# %% [markdown]
# <a href="https://colab.research.google.com/github/Kharis121/Pemrograman-Dasar/blob/main/Test%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya
Nama = "Kharis"
Umur = 19
Jurusan = "RPE"
Semester = 3
Matakuliah = 'Pemrograman Dasar'
Status_lulus= False

"""
print (nama)
print (umur)
pinrt (jurusan)
print (matakuliah)
print (status_lulus)
"""
# Out:
# '\nprint (nama)\nprint (umur)\npinrt (jurusan)\nprint (matakuliah)\nprint (status_lulus)\n'
