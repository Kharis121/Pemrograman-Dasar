# %% [markdown]
# <a href="https://colab.research.google.com/github/Kharis121/Pemrograman-Dasar/blob/main/Test%201.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya
Nama = "Kharis"
Umur = 19
Jurusan = "RPE"
Semester = 3
Matakuliah = 'Pemrograman Dasar'
Status_lulus= False
Hobi = "Kegiatan Positif"
Asal_kota = "Batam"
Tahun_kuliah = 2
Jurusan = 'Teknik Elektro'
Prodi = "RPE"
WNI = True




print (Nama)
print (Umur)
print (Jurusan)
print (Matakuliah)
print (Status_lulus)
print (Hobi)
print (Asal_kota)
print (Tahun_kuliah)
print (Jurusan)
print (Prodi)
print (WNI)
# Out:
# Kharis
# 19
# Teknik Elektro
# Pemrograman Dasar
# False
# Kegiatan Positif
# Batam
# 2
# Teknik Elektro
# RPE
# True
