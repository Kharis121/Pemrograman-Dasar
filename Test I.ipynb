# %% [markdown]
# <a href="https://colab.research.google.com/github/Kharis121/Pemrograman-Dasar/blob/main/Test%20I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata saya
Nama = "Kharis"
Umur = 19
Jurusan = "RPE"
Semester = 3
Matakuliah = 'Pemrograman Dasar'
Status_lulus= False

print (Nama)
print (Umur)
print (Jurusan)
print (Matakuliah)
print (Status_lulus)
# Out:
# Kharis
# 19
# RPE
# Pemrograman Dasar
# False
